# %% [markdown]
# <a href="https://colab.research.google.com/github/harika62/RL-lab/blob/main/lab%20assignment-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Part A - Machine Initialization
machines = ['A', 'B', 'C']
N_play = 10
epsilon = 0.2
N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': [], 'B': [], 'C': []}
Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}
total_reward = 0
print("Modified Epsilon-Greedy Multi-Armed Bandit")
print("------------------------------------------")
for play in range(1, N_play + 1):
    r = random.random()
    best_machine = max(Q, key=Q.get)
    if r < epsilon:
        other_machines = [m for m in machines if m != best_machine]
        selected_machine = random.choice(other_machines)
        print(f"\nPlay {play}: Exploration")
    else:
        selected_machine = best_machine
        print(f"\nPlay {play}: Exploitation")
    print("Selected Machine:", selected_machine)
    reward = float(input(f"Enter reward for machine {selected_machine}: "))
    N[selected_machine] += 1
    R[selected_machine].append(reward)
    Q[selected_machine] = Q[selected_machine] + (
        (reward - Q[selected_machine]) / N[selected_machine]
    )
    total_reward += reward
    print("Updated Q-values:", Q)
# Part F - Display Results
print("\n========== FINAL RESULTS ==========")
print("\nN Table - Participation Count")
for machine in machines:
    print(machine, ":", N[machine])
    print("\nR Table - Rewards")
for machine in machines:
    print(machine, ":", R[machine])
print("\nQ Table - Estimated Values")
for machine in machines:
    print(machine, ":", round(Q[machine], 2))
print("\nTotal Reward Received:", total_reward)
# Out:
# Modified Epsilon-Greedy Multi-Armed Bandit
# ------------------------------------------
#
# Play 1: Exploration
# Selected Machine: B
# Enter reward for machine B: 4
# Updated Q-values: {'A': 0.0, 'B': 4.0, 'C': 0.0}
#
# Play 2: Exploitation
# Selected Machine: B
# Enter reward for machine B: 7
# Updated Q-values: {'A': 0.0, 'B': 5.5, 'C': 0.0}
#
# Play 3: Exploration
# Selected Machine: C
# Enter reward for machine C: 8
# Updated Q-values: {'A': 0.0, 'B': 5.5, 'C': 8.0}
#
# Play 4: Exploitation
# Selected Machine: C
# Enter reward for machine C: 3
# Updated Q-values: {'A': 0.0, 'B': 5.5, 'C': 5.5}
#
# Play 5: Exploration
# Selected Machine: C
# Enter reward for machine C: 8
# Updated Q-values: {'A': 0.0, 'B': 5.5, 'C': 6.333333333333333}
#
# Play 6: Exploitation
# Selected Machine: C
# Enter reward for machine C: 9
# Updated Q-values: {'A': 0.0, 'B': 5.5, 'C': 7.0}
#
# Play 7: Exploitation
# Selected Machine: C
# Enter reward for machine C: 1
# Updated Q-values: {'A': 0.0, 'B': 5.5, 'C': 5.8}
#
# Play 8: Exploitation
# Selected Machine: C
# Enter reward for machine C: 2
# Updated Q-values: {'A': 0.0, 'B': 5.5, 'C': 5.166666666666666}
#
# Play 9: Exploitation
# Selected Machine: B
# Enter reward for machine B: 1
# Updated Q-values: {'A': 0.0, 'B': 4.0, 'C': 5.166666666666666}
#
# Play 10: Exploitation
# Selected Machine: C
# Enter reward for machine C: 16
# Updated Q-values: {'A': 0.0, 'B': 4.0, 'C': 6.7142857142857135}
#
# ========== FINAL RESULTS ==========
#
# N Table - Participation Count
# A : 0
#
# R Table - Rewards
# B : 3
#
# R Table - Rewards
# C : 7
#
# R Table - Rewards
# A : []
# B : [4.0, 7.0, 1.0]
# C : [8.0, 3.0, 8.0, 9.0, 1.0, 2.0, 16.0]
#
# Q Table - Estimated Values
# A : 0.0
# B : 4.0
# C : 6.71
#
# Total Reward Received: 59.0
